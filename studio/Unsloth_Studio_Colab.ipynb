# %% [markdown]
# <a href="https://colab.research.google.com/github/MORAWA-dev/100-days-of-python/blob/master/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys, time
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()

# %%
from google.colab import output
output.serve_kernel_port_as_iframe(8888, height = 1200, width = "100%")
for _ in range(10000): time.sleep(300), print("=", end = "")
# Out:
# {"timestamp": "2026-04-07T13:31:20.942750Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/Qwen3.5-4B-GGUF/Qwen3.5-4B-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-04-07T13:31:40.793637Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-04-07T13:33:22.592158Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 9.94}
# {"timestamp": "2026-04-07T13:33:31.221066Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.87}
# {"timestamp": "2026-04-07T13:33:33.129012Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.82}
# {"timestamp": "2026-04-07T13:33:33.539064Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.28}
# {"timestamp": "2026-04-07T13:33:35.170350Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.27}
# ===={"timestamp": "2026-04-07T13:53:49.752188Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 78.62}
# {"timestamp": "2026-04-07T13:53:50.432452Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 150.41}
# {"timestamp": "2026-04-07T13:53:51.206901Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.27}
# {"timestamp": "2026-04-07T13:53:51.719717Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.25}
# {"timestamp": "2026-04-07T13:53:53.080992Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.96}
# {"timestamp": "2026-04-07T13:53:56.505582Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.41}
# ====={"timestamp": "2026-04-07T14:16:32.160507Z", "level": "info", "event": "Getting model config for: unsloth/gemma-4-E2B-it"}
# {"timestamp": "2026-04-07T14:16:32.172925Z", "level": "info", "event": "Loaded model defaults from /content/unsloth/studio/backend/assets/configs/model_defaults/gemma/unsloth_gemma-4-E2B-it.yaml (via mapping)"}
# {"timestamp": "2026-04-07T14:16:32.180461Z", "level": "info", "event": "Model 'unsloth/gemma-4-E2B-it' needs transformers 5.x -- checking vision via subprocess"}
# {"timestamp": "2026-04-07T14:16:51.773040Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/gemma-4-E2B-it': model_type=gemma4, architectures=['Gemma4ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-04-07T14:16:52.378626Z", "level": "info", "event": "Model 'unsloth/gemma-4-E2B-it' needs transformers 5.x -- checking vision via subprocess"}
# {"timestamp": "2026-04-07T14:17:00.844699Z", "level": "info", "event": "Vision check (subprocess, transformers 5.x) for 'unsloth/gemma-4-E2B-it': model_type=gemma4, architectures=['Gemma4ForConditionalGeneration'], is_vision=True"}
# {"timestamp": "2026-04-07T14:17:03.887889Z", "level": "info", "event": "Model config result for unsloth/gemma-4-E2B-it: is_vision=True, is_embedding=False, audio_type=None, is_lora=False, max_position_embeddings=None"}
# {"timestamp": "2026-04-07T14:17:03.981938Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/config/unsloth/gemma-4-E2B-it", "status_code": 200, "process_time_ms": 31826.63}
# {"timestamp": "2026-04-07T14:17:03.999223Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/system/hardware", "status_code": 200, "process_time_ms": 12.14}
# {"timestamp": "2026-04-07T14:17:04.000351Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 12.45}
# {"timestamp": "2026-04-07T14:17:04.006663Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/huggingface.svg", "status_code": 200, "process_time_ms": 19.82}
# {"timestamp": "2026-04-07T14:17:07.182028Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.23}
# {"timestamp": "2026-04-07T14:17:09.363352Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.42}
# {"timestamp": "2026-04-07T14:17:14.937683Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.42}
# {"timestamp": "2026-04-07T14:17:15.494267Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.46}
# {"timestamp": "2026-04-07T14:17:17.367364Z", "level": "info", "event": "TrainingBackend initialized (subprocess mode)"}
# {"timestamp": "2026-04-07T14:17:17.385361Z", "level": "info", "event": "Checking format for dataset: unsloth/Radiology_mini"}
# {"timestamp": "2026-04-07T14:17:17.494060Z", "level": "info", "event": "Tier 1: loading single file data/test-00000-of-00001.parquet"}
# README.md:   0%|          | 0.00/610 [00:00<?, ?B/s]
# {"timestamp": "2026-04-07T14:17:18.225803Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 4.12}
# {"timestamp": "2026-04-07T14:17:20.331166Z", "level": "info", "event": "Checking format for dataset: unsloth/Radiology_mini"}
# {"timestamp": "2026-04-07T14:17:20.448000Z", "level": "info", "event": "Tier 1: loading single file data/test-00000-of-00001.parquet"}
# {"timestamp": "2026-04-07T14:17:21.168360Z", "level": "info", "event": "Format check result: requires_mapping=False, format=simple_image_text, is_image=True"}
# {"timestamp": "2026-04-07T14:17:21.341190Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 3961.26}
# {"timestamp": "2026-04-07T14:17:23.751439Z", "level": "info", "event": "Format check result: requires_mapping=False, format=simple_image_text, is_image=True"}
# {"timestamp": "2026-04-07T14:17:23.941737Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/datasets/check-format", "status_code": 200, "process_time_ms": 3613.15}
# ======={"timestamp": "2026-04-07T14:54:26.408937Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.28}
# ============{"timestamp": "2026-04-07T15:54:26.695996Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/refresh", "status_code": 200, "process_time_ms": 2.18}
# ====

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
